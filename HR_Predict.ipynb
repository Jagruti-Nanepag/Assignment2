# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
data.head(10)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
# 6   59        No      Travel_Rarely       1324  Research & Development
# 7   30        No      Travel_Rarely       1358  Research & Development
# 8   38        No  Travel_Frequently        216  Research & Development
# 9   36        No      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
f,ax=plt.subplots(figsize=(20,20))
sns.heatmap(data.corr(numeric_only=True),annot=True,linewidths=.5,fmt= '.1f',ax=ax)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 10))
ax = sns.countplot(x=data['OverTime'], palette="husl")  # Use x instead of y for vertical bars

# Add a title
plt.title('OverTime')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 10))
ax = sns.countplot(x=data['MaritalStatus'], palette="husl")  # Use x instead of y for vertical bars

# Add a title
plt.title('OverTime')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(20, 20))
ax = sns.countplot(x=data['JobRole'], palette="husl")  # Use x instead of y for vertical bars

# Add a title
plt.title('OverTime')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 10))
ax = sns.countplot(x=data['Gender'], palette="husl")  # Use x instead of y for vertical bars

# Add a title
plt.title('OverTime')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 10))
ax = sns.countplot(x=data['EducationField'], palette="husl")  # Use x instead of y for vertical bars

# Add a title
plt.title('Educatio fiELD')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 10))
ax = sns.countplot(x=data['Department'], palette="husl")  # Use x instead of y for vertical bars

# Add a title
plt.title('Department')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 10))
ax = sns.countplot(x=data['BusinessTravel'], palette="husl")  # Use x instead of y for vertical bars

# Add a title
plt.title('Business TRavel')

# Show the plot
plt.show()

# %%
sns.catplot(data=data,x='OverTime', y='Age',kind='swarm')

# %%
plt.figure(figsize=(10, 10))
ax = sns.countplot(x=data['TotalWorkingYears'], palette="husl")  # Use x instead of y for vertical bars

# Add a title
plt.title('Business TRavel')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 10))
ax = sns.countplot(x=data['Education'], palette="husl")  # Use x instead of y for vertical bars

# Add a title
plt.title('Business TRavel')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 10))
ax = sns.countplot(x=data['NumCompaniesWorked'], palette="husl")  # Use x instead of y for vertical bars

# Add a title
plt.title('Business TRavel')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 10))
ax = sns.countplot(x=data['DistanceFromHome'], palette="husl")  # Use x instead of y for vertical bars

# Add a title
plt.title('DistanceHomeFromHome')

# Show the plot
plt.show()
